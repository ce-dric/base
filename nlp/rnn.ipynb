# %%
import numpy as np
import os

from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from keras.utils import to_categorical

# %%
fd = open('corpus.txt', 'r')
text = fd.read()
text
# Out:
# '\n딥 러닝이란 무엇인가요?\n우리의 일상에서 머신러닝, 딥 러닝 또는 인공지능과 같은 용어가 활용되는 사례가 늘고 있습니다. 이 용어들은 정확히 무엇을 의미하며 구체적으로 어떤 분야에서 활용될까요?\nBasler는 "기계는 어떻게 학습하나요? "를 통해 머신러닝에 대한 기초적인 내용과 머신러닝이 신경망을 이용해 지능화되는 원리에 대해 설명합니다. 이 문서에서는 머신러닝의 하위 분야 각각에 대해 자세히 살펴보고 이 주제와 관련하여 반복적으로 사용되는 다양한 기술 용어에 대해 설명하고자 합니다. 머신러닝의 하위 분야인 딥 러닝은 인공지능의 한 분야로 간주됩니다.\n1. 인공지능(AI)\nAI는 일반적으로 기계 또는 일반적으로 컴퓨터 프로그램을 통해 인간 행동의 구조를 모방하거나 복제하는 것을 가리킵니다. AI라는 용어는 전문가 시스템, 패턴 분석 시스템 또는 로봇 공학 등 다양한 하위 분야에서 사용됩니다. AI 기반의 시스템은 인간의 행동과 의사 결정 구조를 모방하거나 모델링하기 위해 통계학적 알고리즘, 휴리스틱 절차, 인공 신경망(ANN) 또는 그 밖의 머신러닝 변형 등 다양한 방법을 활용합니다.\n2. 머신러닝\nAI의 하위 분야인 머신러닝은 복수의 예시 데이터에서 일반적인 규칙을 도출하기 위한 자동화된 절차로 구성됩니다. 즉, 예시 데이터로부터 규칙이 "학습"됩니다. 이러한 작업은 사전 정의되고 이해하기 쉬운 알고리즘과 규칙을 적용하여 수행되거나, 딥 러닝의 경우 인공 신경망을 사용하여 수행됩니다. 머신러닝은 지도 학습과 비지도 학습으로 구분됩니다. 지도 학습에서 학습을 위한 샘플 데이터는 입력값과 대응되는 예상 결과(예: 분류)를 모두 포함하는 반면, 비지도 학습에서는 시스템이 입력값 자체에서 가능한 결과를 식별합니다.\n'

# %%
chars = sorted(list(set(text)))

char_to_idx = {char: idx for idx, char in enumerate(chars)}
idx_to_char = {idx: char for idx, char in enumerate(chars)}


voca_size = len(chars)
print("voca size:", voca_size)
# Out:
# voca size: 183

# %%
char_to_idx
# Out:
# {'\n': 0,
#  ' ': 1,
#  '"': 2,
#  '(': 3,
#  ')': 4,
#  ',': 5,
#  '.': 6,
#  '1': 7,
#  '2': 8,
#  ':': 9,
#  '?': 10,
#  'A': 11,
#  'B': 12,
#  'I': 13,
#  'N': 14,
#  'a': 15,
#  'e': 16,
#  'l': 17,
#  'r': 18,
#  's': 19,
#  '가': 20,
#  '각': 21,
#  '간': 22,
#  '값': 23,
#  '같': 24,
#  '거': 25,
#  '것': 26,
#  '게': 27,
#  '결': 28,
#  '경': 29,
#  '계': 30,
#  '고': 31,
#  '공': 32,
#  '과': 33,
#  '관': 34,
#  '구': 35,
#  '규': 36,
#  '그': 37,
#  '기': 38,
#  '까': 39,
#  '나': 40,
#  '내': 41,
#  '는': 42,
#  '늘': 43,
#  '능': 44,
#  '니': 45,
#  '닝': 46,
#  '다': 47,
#  '대': 48,
#  '데': 49,
#  '델': 50,
#  '도': 51,
#  '동': 52,
#  '되': 53,
#  '된': 54,
#  '될': 55,
#  '됩': 56,
#  '두': 57,
#  '들': 58,
#  '등': 59,
#  '딥': 60,
#  '떤': 61,
#  '떻': 62,
#  '또': 63,
#  '라': 64,
#  '란': 65,
#  '램': 66,
#  '러': 67,
#  '력': 68,
#  '련': 69,
#  '례': 70,
#  '로': 71,
#  '류': 72,
#  '를': 73,
#  '리': 74,
#  '링': 75,
#  '망': 76,
#  '머': 77,
#  '며': 78,
#  '면': 79,
#  '명': 80,
#  '모': 81,
#  '무': 82,
#  '문': 83,
#  '미': 84,
#  '밖': 85,
#  '반': 86,
#  '방': 87,
#  '법': 88,
#  '변': 89,
#  '별': 90,
#  '보': 91,
#  '복': 92,
#  '봇': 93,
#  '부': 94,
#  '분': 95,
#  '비': 96,
#  '사': 97,
#  '살': 98,
#  '상': 99,
#  '샘': 100,
#  '서': 101,
#  '석': 102,
#  '설': 103,
#  '성': 104,
#  '세': 105,
#  '수': 106,
#  '술': 107,
#  '쉬': 108,
#  '스': 109,
#  '습': 110,
#  '시': 111,
#  '식': 112,
#  '신': 113,
#  '알': 114,
#  '야': 115,
#  '양': 116,
#  '어': 117,
#  '업': 118,
#  '엇': 119,
#  '에': 120,
#  '여': 121,
#  '예': 122,
#  '와': 123,
#  '요': 124,
#  '용': 125,
#  '우': 126,
#  '운': 127,
#  '원': 128,
#  '위': 129,
#  '으': 130,
#  '은': 131,
#  '을': 132,
#  '응': 133,
#  '의': 134,
#  '이': 135,
#  '인': 136,
#  '일': 137,
#  '입': 138,
#  '있': 139,
#  '자': 140,
#  '작': 141,
#  '적': 142,
#  '전': 143,
#  '절': 144,
#  '정': 145,
#  '제': 146,
#  '조': 147,
#  '주': 148,
#  '즉': 149,
#  '즘': 150,
#  '지': 151,
#  '차': 152,
#  '체': 153,
#  '초': 154,
#  '출': 155,
#  '칙': 156,
#  '컴': 157,
#  '킵': 158,
#  '터': 159,
#  '턴': 160,
#  '템': 161,
#  '통': 162,
#  '틱': 163,
#  '패': 164,
#  '펴': 165,
#  '포': 166,
#  '퓨': 167,
#  '프': 168,
#  '플': 169,
#  '하': 170,
#  '학': 171,
#  '한': 172,
#  '함': 173,
#  '합': 174,
#  '해': 175,
#  '행': 176,
#  '형': 177,
#  '화': 178,
#  '확': 179,
#  '활': 180,
#  '휴': 181,
#  '히': 182}

# %%
# 하이퍼파라미터
seq_length = 5

# 데이터 전처리
input_data = []
target_data = []

for i in range(len(text) - seq_length):
    input_seq = text[i : i + seq_length]
    target_char = text[i + seq_length]
    
    input_data.append([char_to_idx[char] for char in input_seq])
    target_data.append(char_to_idx[target_char])

input_data = np.array(input_data)
target_data = to_categorical(target_data, num_classes=len(chars))

# %%
# 모델 생성
model = Sequential()
model.add(SimpleRNN(64, input_shape=(seq_length, 1), activation="relu"))
model.add(Dense(voca_size, activation="softmax"))

# 모델 컴파일
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# 모델 학습
model.fit(input_data, target_data, epochs=500, batch_size=1, verbose=2)
# Out:
# Epoch 1/500
# 2023-04-19 16:29:29.982679: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-19 16:29:29.983499: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2023-04-19 16:29:30.403515: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node sequential/simple_rnn/while/body/_1/sequential/simple_rnn/while/simple_rnn_cell/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2023-04-19 16:29:30.411660: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:134] tfg_optimizer{any(tfg-consolidate-attrs,tfg-toposort,tfg-shape-inference{graph-version=0},tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential/simple_rnn/while/body/_1/sequential/simple_rnn/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2023-04-19 16:29:30.422735: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:134] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential/simple_rnn/while/body/_1/sequential/simple_rnn/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2023-04-19 16:29:30.423088: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:134] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential/simple_rnn/while/body/_1/sequential/simple_rnn/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2023-04-19 16:29:30.423709: W tensorflow/core/common_runtime/optimize_function_graph_utils.cc:475] Ignoring multi-device function optimization failure: INVALID_ARGUMENT: Node 'sequential/simple_rnn/while/body/_1/sequential/simple_rnn/while/simple_rnn_cell/Relu' does not specify an operation
# 855/855 - 1s - loss: 7.0603 - accuracy: 0.1485 - 1s/epoch - 2ms/step
# Epoch 2/500
# 855/855 - 2s - loss: 4.4163 - accuracy: 0.2117 - 2s/epoch - 2ms/step
# Epoch 3/500
# 855/855 - 3s - loss: 4.0120 - accuracy: 0.2175 - 3s/epoch - 3ms/step
# Epoch 4/500
# 855/855 - 2s - loss: 3.7658 - accuracy: 0.2246 - 2s/epoch - 3ms/step
# Epoch 5/500
# 855/855 - 1s - loss: 3.5622 - accuracy: 0.2246 - 1s/epoch - 1ms/step
# Epoch 6/500
# 855/855 - 1s - loss: 3.3739 - accuracy: 0.2386 - 890ms/epoch - 1ms/step
# Epoch 7/500
# 855/855 - 2s - loss: 3.1658 - accuracy: 0.2327 - 2s/epoch - 2ms/step
# Epoch 8/500
# 855/855 - 1s - loss: 2.9881 - accuracy: 0.2456 - 1s/epoch - 1ms/step
# Epoch 9/500
# 855/855 - 1s - loss: 2.8511 - accuracy: 0.2515 - 791ms/epoch - 926us/step
# Epoch 10/500
# 855/855 - 2s - loss: 2.7475 - accuracy: 0.2620 - 2s/epoch - 2ms/step
# Epoch 11/500
# 855/855 - 2s - loss: 2.6041 - accuracy: 0.2936 - 2s/epoch - 2ms/step
# Epoch 12/500
# 855/855 - 1s - loss: 2.5085 - accuracy: 0.2994 - 804ms/epoch - 940us/step
# Epoch 13/500
# 855/855 - 2s - loss: 2.3891 - accuracy: 0.3205 - 2s/epoch - 2ms/step
# Epoch 14/500
# 855/855 - 1s - loss: 2.3268 - accuracy: 0.3193 - 1s/epoch - 1ms/step
# Epoch 15/500
# 855/855 - 1s - loss: 2.2222 - accuracy: 0.3462 - 1s/epoch - 1ms/step
# Epoch 16/500
# 855/855 - 2s - loss: 2.1193 - accuracy: 0.3532 - 2s/epoch - 2ms/step
# Epoch 17/500
# 855/855 - 2s - loss: 2.0796 - accuracy: 0.3544 - 2s/epoch - 2ms/step
# Epoch 18/500
# 855/855 - 2s - loss: 2.0180 - accuracy: 0.3789 - 2s/epoch - 3ms/step
# Epoch 19/500
# 855/855 - 2s - loss: 1.9581 - accuracy: 0.3801 - 2s/epoch - 3ms/step
# Epoch 20/500
# 855/855 - 1s - loss: 1.8907 - accuracy: 0.3906 - 578ms/epoch - 676us/step
# Epoch 21/500
# 855/855 - 1s - loss: 1.8646 - accuracy: 0.4000 - 1s/epoch - 1ms/step
# Epoch 22/500
# 855/855 - 1s - loss: 1.8119 - accuracy: 0.4082 - 1s/epoch - 1ms/step
# Epoch 23/500
# 855/855 - 1s - loss: 1.7726 - accuracy: 0.4164 - 1s/epoch - 2ms/step
# Epoch 24/500
# 855/855 - 2s - loss: 1.7118 - accuracy: 0.4316 - 2s/epoch - 2ms/step
# Epoch 25/500
# 855/855 - 1s - loss: 1.6659 - accuracy: 0.4608 - 1s/epoch - 1ms/step
# Epoch 26/500
# 855/855 - 1s - loss: 1.6456 - accuracy: 0.4468 - 1s/epoch - 2ms/step
# Epoch 27/500
# 855/855 - 1s - loss: 1.6363 - accuracy: 0.4503 - 1s/epoch - 2ms/step
# Epoch 28/500
# 855/855 - 1s - loss: 1.5824 - accuracy: 0.4749 - 654ms/epoch - 765us/step
# Epoch 29/500
# 855/855 - 1s - loss: 1.6011 - accuracy: 0.4690 - 872ms/epoch - 1ms/step
# Epoch 30/500
# 855/855 - 2s - loss: 1.5175 - accuracy: 0.4877 - 2s/epoch - 2ms/step
# Epoch 31/500
# 855/855 - 1s - loss: 1.5048 - accuracy: 0.5006 - 1s/epoch - 2ms/step
# Epoch 32/500
# 855/855 - 2s - loss: 1.5025 - accuracy: 0.4971 - 2s/epoch - 2ms/step
# Epoch 33/500
# 855/855 - 1s - loss: 1.4534 - accuracy: 0.5076 - 1s/epoch - 2ms/step
# Epoch 34/500
# 855/855 - 2s - loss: 1.4199 - accuracy: 0.5181 - 2s/epoch - 2ms/step
# Epoch 35/500
# 855/855 - 1s - loss: 1.4124 - accuracy: 0.5146 - 1s/epoch - 1ms/step
# Epoch 36/500
# 855/855 - 1s - loss: 1.4242 - accuracy: 0.5240 - 1s/epoch - 1ms/step
# Epoch 37/500
# 855/855 - 1s - loss: 1.3998 - accuracy: 0.5251 - 1s/epoch - 1ms/step
# Epoch 38/500
# 855/855 - 2s - loss: 1.3207 - accuracy: 0.5240 - 2s/epoch - 2ms/step
# Epoch 39/500
# 855/855 - 1s - loss: 1.3219 - accuracy: 0.5427 - 799ms/epoch - 935us/step
# Epoch 40/500
# 855/855 - 1s - loss: 1.3164 - accuracy: 0.5544 - 1s/epoch - 2ms/step
# Epoch 41/500
# 855/855 - 1s - loss: 1.2990 - accuracy: 0.5415 - 683ms/epoch - 798us/step
# Epoch 42/500
# 855/855 - 1s - loss: 1.3434 - accuracy: 0.5380 - 829ms/epoch - 970us/step
# Epoch 43/500
# 855/855 - 2s - loss: 1.2594 - accuracy: 0.5673 - 2s/epoch - 3ms/step
# Epoch 44/500
# 855/855 - 1s - loss: 1.2214 - accuracy: 0.5719 - 831ms/epoch - 972us/step
# Epoch 45/500
# 855/855 - 2s - loss: 1.1649 - accuracy: 0.5918 - 2s/epoch - 3ms/step
# Epoch 46/500
# 855/855 - 2s - loss: 1.2184 - accuracy: 0.5696 - 2s/epoch - 2ms/step
# Epoch 47/500
# 855/855 - 1s - loss: 1.1731 - accuracy: 0.5825 - 768ms/epoch - 898us/step
# Epoch 48/500
# 855/855 - 1s - loss: 1.1971 - accuracy: 0.5801 - 1s/epoch - 2ms/step
# Epoch 49/500
# 855/855 - 3s - loss: 1.1970 - accuracy: 0.5696 - 3s/epoch - 3ms/step
# Epoch 50/500
# 855/855 - 2s - loss: 1.2236 - accuracy: 0.5801 - 2s/epoch - 3ms/step
# Epoch 51/500
# 855/855 - 2s - loss: 1.1438 - accuracy: 0.5801 - 2s/epoch - 2ms/step
# Epoch 52/500
# 855/855 - 1s - loss: 1.1040 - accuracy: 0.6070 - 656ms/epoch - 768us/step
# Epoch 53/500
# 855/855 - 2s - loss: 1.1701 - accuracy: 0.5906 - 2s/epoch - 2ms/step
# Epoch 54/500
# 855/855 - 1s - loss: 1.1199 - accuracy: 0.6023 - 907ms/epoch - 1ms/step
# Epoch 55/500
# 855/855 - 1s - loss: 1.1320 - accuracy: 0.5953 - 700ms/epoch - 818us/step
# Epoch 56/500
# 855/855 - 2s - loss: 1.0876 - accuracy: 0.5977 - 2s/epoch - 2ms/step
# Epoch 57/500
# 855/855 - 2s - loss: 1.0567 - accuracy: 0.6164 - 2s/epoch - 2ms/step
# Epoch 58/500
# 855/855 - 1s - loss: 1.0978 - accuracy: 0.5813 - 860ms/epoch - 1ms/step
# Epoch 59/500
# 855/855 - 2s - loss: 1.0675 - accuracy: 0.6175 - 2s/epoch - 2ms/step
# Epoch 60/500
# 855/855 - 2s - loss: 1.0401 - accuracy: 0.6327 - 2s/epoch - 2ms/step
# Epoch 61/500
# 855/855 - 2s - loss: 1.0865 - accuracy: 0.6094 - 2s/epoch - 2ms/step
# Epoch 62/500
# 855/855 - 2s - loss: 1.0109 - accuracy: 0.6269 - 2s/epoch - 2ms/step
# Epoch 63/500
# 855/855 - 1s - loss: 1.1202 - accuracy: 0.6035 - 1s/epoch - 1ms/step
# Epoch 64/500
# 855/855 - 1s - loss: 1.0340 - accuracy: 0.6269 - 890ms/epoch - 1ms/step
# Epoch 65/500
# 855/855 - 1s - loss: 1.0003 - accuracy: 0.6526 - 1s/epoch - 1ms/step
# Epoch 66/500
# 855/855 - 1s - loss: 1.0030 - accuracy: 0.6398 - 602ms/epoch - 704us/step
# Epoch 67/500
# 855/855 - 1s - loss: 0.9888 - accuracy: 0.6222 - 1s/epoch - 1ms/step
# Epoch 68/500
# 855/855 - 2s - loss: 0.9872 - accuracy: 0.6292 - 2s/epoch - 2ms/step
# Epoch 69/500
# 855/855 - 2s - loss: 1.0265 - accuracy: 0.6351 - 2s/epoch - 3ms/step
# Epoch 70/500
# 855/855 - 2s - loss: 0.9833 - accuracy: 0.6339 - 2s/epoch - 2ms/step
# Epoch 71/500
# 855/855 - 3s - loss: 1.1267 - accuracy: 0.6070 - 3s/epoch - 3ms/step
# Epoch 72/500
# 855/855 - 2s - loss: 0.9510 - accuracy: 0.6643 - 2s/epoch - 2ms/step
# Epoch 73/500
# 855/855 - 1s - loss: 1.0475 - accuracy: 0.6339 - 1s/epoch - 2ms/step
# Epoch 74/500
# 855/855 - 2s - loss: 0.9384 - accuracy: 0.6503 - 2s/epoch - 2ms/step
# Epoch 75/500
# 855/855 - 1s - loss: 0.9409 - accuracy: 0.6433 - 782ms/epoch - 915us/step
# Epoch 76/500
# 855/855 - 1s - loss: 0.9445 - accuracy: 0.6515 - 812ms/epoch - 950us/step
# Epoch 77/500
# 855/855 - 1s - loss: 0.9468 - accuracy: 0.6608 - 742ms/epoch - 868us/step
# Epoch 78/500
# 855/855 - 1s - loss: 0.9719 - accuracy: 0.6386 - 696ms/epoch - 814us/step
# Epoch 79/500
# 855/855 - 1s - loss: 0.9646 - accuracy: 0.6398 - 838ms/epoch - 980us/step
# Epoch 80/500
# 855/855 - 1s - loss: 0.9286 - accuracy: 0.6667 - 729ms/epoch - 853us/step
# Epoch 81/500
# 855/855 - 2s - loss: 0.9796 - accuracy: 0.6421 - 2s/epoch - 3ms/step
# Epoch 82/500
# 855/855 - 1s - loss: 0.9315 - accuracy: 0.6468 - 751ms/epoch - 878us/step
# Epoch 83/500
# 855/855 - 1s - loss: 0.8492 - accuracy: 0.6772 - 664ms/epoch - 777us/step
# Epoch 84/500
# 855/855 - 1s - loss: 0.9113 - accuracy: 0.6608 - 671ms/epoch - 784us/step
# Epoch 85/500
# 855/855 - 2s - loss: 0.9528 - accuracy: 0.6538 - 2s/epoch - 2ms/step
# Epoch 86/500
# 855/855 - 1s - loss: 0.9521 - accuracy: 0.6620 - 796ms/epoch - 931us/step
# Epoch 87/500
# 855/855 - 1s - loss: 0.9427 - accuracy: 0.6503 - 1s/epoch - 1ms/step
# Epoch 88/500
# 855/855 - 1s - loss: 0.8606 - accuracy: 0.6725 - 1s/epoch - 2ms/step
# Epoch 89/500
# 855/855 - 1s - loss: 0.9069 - accuracy: 0.6702 - 1s/epoch - 2ms/step
# Epoch 90/500
# 855/855 - 1s - loss: 0.9532 - accuracy: 0.6643 - 980ms/epoch - 1ms/step
# Epoch 91/500
# 855/855 - 1s - loss: 0.8738 - accuracy: 0.6725 - 1s/epoch - 2ms/step
# Epoch 92/500
# 855/855 - 1s - loss: 0.8574 - accuracy: 0.6772 - 691ms/epoch - 808us/step
# Epoch 93/500
# 855/855 - 1s - loss: 0.9663 - accuracy: 0.6526 - 1s/epoch - 1ms/step
# Epoch 94/500
# 855/855 - 0s - loss: 0.9737 - accuracy: 0.6550 - 475ms/epoch - 556us/step
# Epoch 95/500
# 855/855 - 1s - loss: 0.8489 - accuracy: 0.6713 - 588ms/epoch - 688us/step
# Epoch 96/500
# 855/855 - 2s - loss: 0.8517 - accuracy: 0.6854 - 2s/epoch - 2ms/step
# Epoch 97/500
# 855/855 - 1s - loss: 0.9077 - accuracy: 0.6690 - 979ms/epoch - 1ms/step
# Epoch 98/500
# 855/855 - 1s - loss: 0.9368 - accuracy: 0.6515 - 1s/epoch - 1ms/step
# Epoch 99/500
# 855/855 - 2s - loss: 0.8258 - accuracy: 0.6889 - 2s/epoch - 3ms/step
# Epoch 100/500
# 855/855 - 1s - loss: 0.8240 - accuracy: 0.6842 - 702ms/epoch - 821us/step
# Epoch 101/500
# 855/855 - 1s - loss: 0.8371 - accuracy: 0.6795 - 694ms/epoch - 812us/step
# Epoch 102/500
# 855/855 - 1s - loss: 0.8926 - accuracy: 0.6713 - 763ms/epoch - 893us/step
# Epoch 103/500
# 855/855 - 1s - loss: 0.7874 - accuracy: 0.6784 - 979ms/epoch - 1ms/step
# Epoch 104/500
# 855/855 - 1s - loss: 0.9031 - accuracy: 0.6795 - 1s/epoch - 1ms/step
# Epoch 105/500
# 855/855 - 2s - loss: 0.7999 - accuracy: 0.7076 - 2s/epoch - 2ms/step
# Epoch 106/500
# 855/855 - 1s - loss: 0.8070 - accuracy: 0.7006 - 1s/epoch - 1ms/step
# Epoch 107/500
# 855/855 - 1s - loss: 0.8412 - accuracy: 0.6807 - 1s/epoch - 1ms/step
# Epoch 108/500
# 855/855 - 1s - loss: 0.8878 - accuracy: 0.6690 - 1s/epoch - 1ms/step
# Epoch 109/500
# 855/855 - 1s - loss: 0.7737 - accuracy: 0.7053 - 846ms/epoch - 990us/step
# Epoch 110/500
# 855/855 - 1s - loss: 0.7425 - accuracy: 0.7228 - 1s/epoch - 1ms/step
# Epoch 111/500
# 855/855 - 2s - loss: 0.9391 - accuracy: 0.6713 - 2s/epoch - 3ms/step
# Epoch 112/500
# 855/855 - 2s - loss: 0.7832 - accuracy: 0.6959 - 2s/epoch - 2ms/step
# Epoch 113/500
# 855/855 - 1s - loss: 0.7848 - accuracy: 0.7216 - 1s/epoch - 1ms/step
# Epoch 114/500
# 855/855 - 1s - loss: 0.9416 - accuracy: 0.6725 - 1s/epoch - 2ms/step
# Epoch 115/500
# 855/855 - 2s - loss: 0.8566 - accuracy: 0.6772 - 2s/epoch - 3ms/step
# Epoch 116/500
# 855/855 - 2s - loss: 0.7568 - accuracy: 0.7099 - 2s/epoch - 3ms/step
# Epoch 117/500
# 855/855 - 1s - loss: 0.7829 - accuracy: 0.6936 - 1s/epoch - 1ms/step
# Epoch 118/500
# 855/855 - 2s - loss: 0.8511 - accuracy: 0.6982 - 2s/epoch - 2ms/step
# Epoch 119/500
# 855/855 - 1s - loss: 0.8084 - accuracy: 0.6901 - 1s/epoch - 1ms/step
# Epoch 120/500
# 855/855 - 1s - loss: 0.8543 - accuracy: 0.6889 - 970ms/epoch - 1ms/step
# Epoch 121/500
# 855/855 - 2s - loss: 0.7202 - accuracy: 0.7181 - 2s/epoch - 2ms/step
# Epoch 122/500
# 855/855 - 2s - loss: 0.8322 - accuracy: 0.6982 - 2s/epoch - 2ms/step
# Epoch 123/500
# 855/855 - 1s - loss: 0.8456 - accuracy: 0.6795 - 1s/epoch - 1ms/step
# Epoch 124/500
# 855/855 - 2s - loss: 0.8145 - accuracy: 0.7018 - 2s/epoch - 2ms/step
# Epoch 125/500
# 855/855 - 1s - loss: 0.7653 - accuracy: 0.7041 - 1s/epoch - 1ms/step
# Epoch 126/500
# 855/855 - 2s - loss: 0.8667 - accuracy: 0.6936 - 2s/epoch - 2ms/step
# Epoch 127/500
# 855/855 - 2s - loss: 0.7709 - accuracy: 0.7170 - 2s/epoch - 2ms/step
# Epoch 128/500
# 855/855 - 1s - loss: 0.8290 - accuracy: 0.6936 - 1s/epoch - 2ms/step
# Epoch 129/500
# 855/855 - 1s - loss: 0.8498 - accuracy: 0.7018 - 953ms/epoch - 1ms/step
# Epoch 130/500
# 855/855 - 1s - loss: 0.7528 - accuracy: 0.7263 - 954ms/epoch - 1ms/step
# Epoch 131/500
# 855/855 - 1s - loss: 0.7790 - accuracy: 0.7088 - 1s/epoch - 2ms/step
# Epoch 132/500
# 855/855 - 2s - loss: 0.6919 - accuracy: 0.7368 - 2s/epoch - 3ms/step
# Epoch 133/500
# 855/855 - 2s - loss: 0.8236 - accuracy: 0.6912 - 2s/epoch - 3ms/step
# Epoch 134/500
# 855/855 - 2s - loss: 0.7652 - accuracy: 0.7006 - 2s/epoch - 2ms/step
# Epoch 135/500
# 855/855 - 2s - loss: 0.7020 - accuracy: 0.7298 - 2s/epoch - 2ms/step
# Epoch 136/500
# 855/855 - 1s - loss: 0.7749 - accuracy: 0.7076 - 1s/epoch - 2ms/step
# Epoch 137/500
# 855/855 - 1s - loss: 0.7622 - accuracy: 0.6982 - 1s/epoch - 2ms/step
# Epoch 138/500
# 855/855 - 2s - loss: 0.7632 - accuracy: 0.7181 - 2s/epoch - 2ms/step
# Epoch 139/500
# 855/855 - 1s - loss: 0.7543 - accuracy: 0.7158 - 1s/epoch - 1ms/step
# Epoch 140/500
# 855/855 - 1s - loss: 0.8555 - accuracy: 0.7006 - 907ms/epoch - 1ms/step
# Epoch 141/500
# 855/855 - 1s - loss: 0.6771 - accuracy: 0.7439 - 1s/epoch - 2ms/step
# Epoch 142/500
# 855/855 - 2s - loss: 0.7609 - accuracy: 0.7170 - 2s/epoch - 2ms/step
# Epoch 143/500
# 855/855 - 1s - loss: 0.7621 - accuracy: 0.7053 - 1s/epoch - 1ms/step
# Epoch 144/500
# 855/855 - 2s - loss: 0.8051 - accuracy: 0.7181 - 2s/epoch - 2ms/step
# Epoch 145/500
# 855/855 - 2s - loss: 0.7515 - accuracy: 0.7228 - 2s/epoch - 2ms/step
# Epoch 146/500
# 855/855 - 1s - loss: 0.7585 - accuracy: 0.7193 - 1s/epoch - 2ms/step
# Epoch 147/500
# 855/855 - 1s - loss: 0.7523 - accuracy: 0.7158 - 1s/epoch - 1ms/step
# Epoch 148/500
# 855/855 - 1s - loss: 0.8084 - accuracy: 0.7088 - 1s/epoch - 2ms/step
# Epoch 149/500
# 855/855 - 2s - loss: 0.8009 - accuracy: 0.7228 - 2s/epoch - 2ms/step
# Epoch 150/500
# 855/855 - 1s - loss: 0.6885 - accuracy: 0.7287 - 1s/epoch - 2ms/step
# Epoch 151/500
# 855/855 - 2s - loss: 0.7757 - accuracy: 0.7228 - 2s/epoch - 2ms/step
# Epoch 152/500
# 855/855 - 1s - loss: 0.7444 - accuracy: 0.7170 - 1s/epoch - 2ms/step
# Epoch 153/500
# 855/855 - 1s - loss: 0.8904 - accuracy: 0.7018 - 662ms/epoch - 774us/step
# Epoch 154/500
# 855/855 - 1s - loss: 0.6623 - accuracy: 0.7520 - 658ms/epoch - 769us/step
# Epoch 155/500
# 855/855 - 1s - loss: 0.8153 - accuracy: 0.7111 - 973ms/epoch - 1ms/step
# Epoch 156/500
# 855/855 - 2s - loss: 0.7785 - accuracy: 0.7170 - 2s/epoch - 2ms/step
# Epoch 157/500
# 855/855 - 1s - loss: 0.7833 - accuracy: 0.7170 - 1s/epoch - 1ms/step
# Epoch 158/500
# 855/855 - 1s - loss: 0.7571 - accuracy: 0.7298 - 1s/epoch - 1ms/step
# Epoch 159/500
# 855/855 - 1s - loss: 0.6956 - accuracy: 0.7427 - 823ms/epoch - 963us/step
# Epoch 160/500
# 855/855 - 1s - loss: 0.7572 - accuracy: 0.7088 - 806ms/epoch - 943us/step
# Epoch 161/500
# 855/855 - 1s - loss: 0.7104 - accuracy: 0.7544 - 1s/epoch - 2ms/step
# Epoch 162/500
# 855/855 - 2s - loss: 0.7769 - accuracy: 0.7216 - 2s/epoch - 2ms/step
# Epoch 163/500
# 855/855 - 2s - loss: 0.7887 - accuracy: 0.7333 - 2s/epoch - 3ms/step
# Epoch 164/500
# 855/855 - 1s - loss: 0.7909 - accuracy: 0.7287 - 1s/epoch - 1ms/step
# Epoch 165/500
# 855/855 - 1s - loss: 0.7040 - accuracy: 0.7497 - 807ms/epoch - 944us/step
# Epoch 166/500
# 855/855 - 1s - loss: 0.7547 - accuracy: 0.7170 - 878ms/epoch - 1ms/step
# Epoch 167/500
# 855/855 - 1s - loss: 0.8118 - accuracy: 0.7135 - 1s/epoch - 1ms/step
# Epoch 168/500
# 855/855 - 1s - loss: 0.5533 - accuracy: 0.7789 - 786ms/epoch - 919us/step
# Epoch 169/500
# 855/855 - 1s - loss: 0.6679 - accuracy: 0.7591 - 984ms/epoch - 1ms/step
# Epoch 170/500
# 855/855 - 1s - loss: 0.7620 - accuracy: 0.7029 - 1s/epoch - 1ms/step
# Epoch 171/500
# 855/855 - 1s - loss: 0.8481 - accuracy: 0.7018 - 1s/epoch - 1ms/step
# Epoch 172/500
# 855/855 - 1s - loss: 0.6741 - accuracy: 0.7509 - 1s/epoch - 2ms/step
# Epoch 173/500
# 855/855 - 2s - loss: 0.9332 - accuracy: 0.6912 - 2s/epoch - 2ms/step
# Epoch 174/500
# 855/855 - 1s - loss: 0.6421 - accuracy: 0.7380 - 1s/epoch - 2ms/step
# Epoch 175/500
# 855/855 - 1s - loss: 0.7290 - accuracy: 0.7392 - 833ms/epoch - 975us/step
# Epoch 176/500
# 855/855 - 1s - loss: 0.7016 - accuracy: 0.7427 - 1s/epoch - 2ms/step
# Epoch 177/500
# 855/855 - 2s - loss: 0.7174 - accuracy: 0.7310 - 2s/epoch - 2ms/step
# Epoch 178/500
# 855/855 - 1s - loss: 0.6549 - accuracy: 0.7602 - 923ms/epoch - 1ms/step
# Epoch 179/500
# 855/855 - 1s - loss: 0.7656 - accuracy: 0.7333 - 704ms/epoch - 824us/step
# Epoch 180/500
# 855/855 - 1s - loss: 0.8399 - accuracy: 0.6994 - 1s/epoch - 2ms/step
# Epoch 181/500
# 855/855 - 2s - loss: 0.6290 - accuracy: 0.7520 - 2s/epoch - 2ms/step
# Epoch 182/500
# 855/855 - 2s - loss: 0.6302 - accuracy: 0.7450 - 2s/epoch - 2ms/step
# Epoch 183/500
# 855/855 - 1s - loss: 0.7601 - accuracy: 0.7310 - 824ms/epoch - 963us/step
# Epoch 184/500
# 855/855 - 2s - loss: 0.7096 - accuracy: 0.7415 - 2s/epoch - 2ms/step
# Epoch 185/500
# 855/855 - 1s - loss: 0.7449 - accuracy: 0.7357 - 761ms/epoch - 891us/step
# Epoch 186/500
# 855/855 - 0s - loss: 0.8367 - accuracy: 0.7216 - 491ms/epoch - 574us/step
# Epoch 187/500
# 855/855 - 1s - loss: 0.6746 - accuracy: 0.7450 - 1s/epoch - 2ms/step
# Epoch 188/500
# 855/855 - 1s - loss: 0.6002 - accuracy: 0.7591 - 1s/epoch - 1ms/step
# Epoch 189/500
# 855/855 - 1s - loss: 0.7869 - accuracy: 0.7135 - 1s/epoch - 2ms/step
# Epoch 190/500
# 855/855 - 2s - loss: 0.7299 - accuracy: 0.7322 - 2s/epoch - 2ms/step
# Epoch 191/500
# 855/855 - 1s - loss: 0.7444 - accuracy: 0.7404 - 1s/epoch - 1ms/step
# Epoch 192/500
# 855/855 - 1s - loss: 0.6869 - accuracy: 0.7579 - 1s/epoch - 2ms/step
# Epoch 193/500
# 855/855 - 1s - loss: 0.6728 - accuracy: 0.7404 - 1s/epoch - 1ms/step
# Epoch 194/500
# 855/855 - 1s - loss: 0.7219 - accuracy: 0.7310 - 1s/epoch - 2ms/step
# Epoch 195/500
# 855/855 - 1s - loss: 0.6533 - accuracy: 0.7509 - 1s/epoch - 1ms/step
# Epoch 196/500
# 855/855 - 1s - loss: 0.6486 - accuracy: 0.7544 - 779ms/epoch - 912us/step
# Epoch 197/500
# 855/855 - 1s - loss: 0.7737 - accuracy: 0.7357 - 662ms/epoch - 775us/step
# Epoch 198/500
# 855/855 - 1s - loss: 0.8058 - accuracy: 0.7263 - 737ms/epoch - 862us/step
# Epoch 199/500
# 855/855 - 2s - loss: 0.5906 - accuracy: 0.7673 - 2s/epoch - 2ms/step
# Epoch 200/500
# 855/855 - 3s - loss: 0.8360 - accuracy: 0.7111 - 3s/epoch - 3ms/step
# Epoch 201/500
# 855/855 - 1s - loss: 0.6641 - accuracy: 0.7614 - 1s/epoch - 1ms/step
# Epoch 202/500
# 855/855 - 1s - loss: 0.5757 - accuracy: 0.7719 - 1s/epoch - 2ms/step
# Epoch 203/500
# 855/855 - 3s - loss: 0.7711 - accuracy: 0.7181 - 3s/epoch - 3ms/step
# Epoch 204/500
# 855/855 - 2s - loss: 0.6351 - accuracy: 0.7813 - 2s/epoch - 3ms/step
# Epoch 205/500
# 855/855 - 2s - loss: 0.7357 - accuracy: 0.7415 - 2s/epoch - 2ms/step
# Epoch 206/500
# 855/855 - 3s - loss: 0.6769 - accuracy: 0.7602 - 3s/epoch - 3ms/step
# Epoch 207/500
# 855/855 - 2s - loss: 0.7750 - accuracy: 0.7298 - 2s/epoch - 2ms/step
# Epoch 208/500
# 855/855 - 1s - loss: 0.5962 - accuracy: 0.7696 - 708ms/epoch - 829us/step
# Epoch 209/500
# 855/855 - 1s - loss: 0.7997 - accuracy: 0.7240 - 1s/epoch - 1ms/step
# Epoch 210/500
# 855/855 - 1s - loss: 0.7026 - accuracy: 0.7509 - 1s/epoch - 2ms/step
# Epoch 211/500
# 855/855 - 2s - loss: 0.7724 - accuracy: 0.7181 - 2s/epoch - 2ms/step
# Epoch 212/500
# 855/855 - 1s - loss: 0.6148 - accuracy: 0.7404 - 1s/epoch - 2ms/step
# Epoch 213/500
# 855/855 - 1s - loss: 0.7157 - accuracy: 0.7450 - 1s/epoch - 1ms/step
# Epoch 214/500
# 855/855 - 2s - loss: 0.5236 - accuracy: 0.7930 - 2s/epoch - 2ms/step
# Epoch 215/500
# 855/855 - 1s - loss: 0.7372 - accuracy: 0.7474 - 847ms/epoch - 990us/step
# Epoch 216/500
# 855/855 - 1s - loss: 0.8007 - accuracy: 0.7076 - 746ms/epoch - 873us/step
# Epoch 217/500
# 855/855 - 2s - loss: 0.7211 - accuracy: 0.7404 - 2s/epoch - 2ms/step
# Epoch 218/500
# 855/855 - 2s - loss: 0.6927 - accuracy: 0.7439 - 2s/epoch - 2ms/step
# Epoch 219/500
# 855/855 - 2s - loss: 0.7010 - accuracy: 0.7263 - 2s/epoch - 2ms/step
# Epoch 220/500
# 855/855 - 1s - loss: 0.6419 - accuracy: 0.7661 - 1s/epoch - 1ms/step
# Epoch 221/500
# 855/855 - 2s - loss: 0.6125 - accuracy: 0.7602 - 2s/epoch - 2ms/step
# Epoch 222/500
# 855/855 - 1s - loss: 0.7324 - accuracy: 0.7427 - 1s/epoch - 2ms/step
# Epoch 223/500
# 855/855 - 1s - loss: 0.7648 - accuracy: 0.7298 - 688ms/epoch - 805us/step
# Epoch 224/500
# 855/855 - 1s - loss: 0.6551 - accuracy: 0.7567 - 724ms/epoch - 846us/step
# Epoch 225/500
# 855/855 - 0s - loss: 0.6457 - accuracy: 0.7626 - 478ms/epoch - 559us/step
# Epoch 226/500
# 855/855 - 1s - loss: 0.7764 - accuracy: 0.7380 - 745ms/epoch - 871us/step
# Epoch 227/500
# 855/855 - 1s - loss: 0.6663 - accuracy: 0.7544 - 753ms/epoch - 880us/step
# Epoch 228/500
# 855/855 - 1s - loss: 0.7137 - accuracy: 0.7415 - 689ms/epoch - 806us/step
# Epoch 229/500
# 855/855 - 1s - loss: 0.6702 - accuracy: 0.7602 - 736ms/epoch - 861us/step
# Epoch 230/500
# 855/855 - 1s - loss: 0.5969 - accuracy: 0.7743 - 1s/epoch - 1ms/step
# Epoch 231/500
# 855/855 - 2s - loss: 0.7408 - accuracy: 0.7556 - 2s/epoch - 2ms/step
# Epoch 232/500
# 855/855 - 2s - loss: 0.7351 - accuracy: 0.7567 - 2s/epoch - 3ms/step
# Epoch 233/500
# 855/855 - 1s - loss: 0.7135 - accuracy: 0.7357 - 1s/epoch - 1ms/step
# Epoch 234/500
# 855/855 - 1s - loss: 0.5950 - accuracy: 0.7637 - 583ms/epoch - 682us/step
# Epoch 235/500
# 855/855 - 1s - loss: 0.8951 - accuracy: 0.7205 - 865ms/epoch - 1ms/step
# Epoch 236/500
# 855/855 - 2s - loss: 0.6723 - accuracy: 0.7532 - 2s/epoch - 2ms/step
# Epoch 237/500
# 855/855 - 2s - loss: 0.5262 - accuracy: 0.7848 - 2s/epoch - 3ms/step
# Epoch 238/500
# 855/855 - 1s - loss: 0.6080 - accuracy: 0.7602 - 1s/epoch - 1ms/step
# Epoch 239/500
# 855/855 - 1s - loss: 0.8795 - accuracy: 0.7099 - 802ms/epoch - 938us/step
# Epoch 240/500
# 855/855 - 1s - loss: 0.6394 - accuracy: 0.7614 - 999ms/epoch - 1ms/step
# Epoch 241/500
# 855/855 - 1s - loss: 0.6414 - accuracy: 0.7696 - 804ms/epoch - 940us/step
# Epoch 242/500
# 855/855 - 2s - loss: 0.6672 - accuracy: 0.7556 - 2s/epoch - 2ms/step
# Epoch 243/500
# 855/855 - 2s - loss: 0.7785 - accuracy: 0.7439 - 2s/epoch - 2ms/step
# Epoch 244/500
# 855/855 - 2s - loss: 0.7370 - accuracy: 0.7298 - 2s/epoch - 2ms/step
# Epoch 245/500
# 855/855 - 2s - loss: 0.5800 - accuracy: 0.7801 - 2s/epoch - 2ms/step
# Epoch 246/500
# 855/855 - 2s - loss: 0.6742 - accuracy: 0.7602 - 2s/epoch - 2ms/step
# Epoch 247/500
# 855/855 - 1s - loss: 0.6686 - accuracy: 0.7532 - 1s/epoch - 2ms/step
# Epoch 248/500
# 855/855 - 1s - loss: 0.8424 - accuracy: 0.7228 - 1s/epoch - 1ms/step
# Epoch 249/500
# 855/855 - 1s - loss: 0.6741 - accuracy: 0.7485 - 757ms/epoch - 886us/step
# Epoch 250/500
# 855/855 - 2s - loss: 0.6083 - accuracy: 0.7708 - 2s/epoch - 2ms/step
# Epoch 251/500
# 855/855 - 1s - loss: 0.8079 - accuracy: 0.7158 - 1s/epoch - 1ms/step
# Epoch 252/500
# 855/855 - 2s - loss: 0.6612 - accuracy: 0.7485 - 2s/epoch - 2ms/step
# Epoch 253/500
# 855/855 - 2s - loss: 0.7740 - accuracy: 0.7532 - 2s/epoch - 2ms/step
# Epoch 254/500
# 855/855 - 2s - loss: 0.6672 - accuracy: 0.7591 - 2s/epoch - 2ms/step
# Epoch 255/500
# 855/855 - 2s - loss: 0.6187 - accuracy: 0.7684 - 2s/epoch - 2ms/step
# Epoch 256/500
# 855/855 - 1s - loss: 0.5941 - accuracy: 0.7836 - 672ms/epoch - 786us/step
# Epoch 257/500
# 855/855 - 1s - loss: 0.7770 - accuracy: 0.7404 - 699ms/epoch - 818us/step
# Epoch 258/500
# 855/855 - 1s - loss: 0.5662 - accuracy: 0.7766 - 632ms/epoch - 739us/step
# Epoch 259/500
# 855/855 - 1s - loss: 0.7848 - accuracy: 0.7497 - 814ms/epoch - 952us/step
# Epoch 260/500
# 855/855 - 2s - loss: 0.7107 - accuracy: 0.7485 - 2s/epoch - 2ms/step
# Epoch 261/500
# 855/855 - 1s - loss: 0.5335 - accuracy: 0.7942 - 940ms/epoch - 1ms/step
# Epoch 262/500
# 855/855 - 1s - loss: 0.6354 - accuracy: 0.7626 - 1s/epoch - 2ms/step
# Epoch 263/500
# 855/855 - 1s - loss: 0.7663 - accuracy: 0.7275 - 1s/epoch - 1ms/step
# Epoch 264/500
# 855/855 - 1s - loss: 0.6504 - accuracy: 0.7614 - 804ms/epoch - 941us/step
# Epoch 265/500
# 855/855 - 1s - loss: 0.6454 - accuracy: 0.7673 - 629ms/epoch - 735us/step
# Epoch 266/500
# 855/855 - 1s - loss: 0.6822 - accuracy: 0.7614 - 1s/epoch - 1ms/step
# Epoch 267/500
# 855/855 - 1s - loss: 0.6736 - accuracy: 0.7637 - 959ms/epoch - 1ms/step
# Epoch 268/500
# 855/855 - 1s - loss: 0.9275 - accuracy: 0.7088 - 822ms/epoch - 961us/step
# Epoch 269/500
# 855/855 - 1s - loss: 0.6304 - accuracy: 0.7673 - 1s/epoch - 1ms/step
# Epoch 270/500
# 855/855 - 2s - loss: 0.6114 - accuracy: 0.7556 - 2s/epoch - 2ms/step
# Epoch 271/500
# 855/855 - 1s - loss: 0.6194 - accuracy: 0.7801 - 639ms/epoch - 748us/step
# Epoch 272/500
# 855/855 - 1s - loss: 0.6314 - accuracy: 0.7614 - 745ms/epoch - 872us/step
# Epoch 273/500
# 855/855 - 1s - loss: 0.7361 - accuracy: 0.7708 - 944ms/epoch - 1ms/step
# Epoch 274/500
# 855/855 - 1s - loss: 0.6861 - accuracy: 0.7591 - 935ms/epoch - 1ms/step
# Epoch 275/500
# 855/855 - 1s - loss: 0.7201 - accuracy: 0.7345 - 1s/epoch - 2ms/step
# Epoch 276/500
# 855/855 - 2s - loss: 0.6168 - accuracy: 0.7778 - 2s/epoch - 2ms/step
# Epoch 277/500
# 855/855 - 1s - loss: 0.6108 - accuracy: 0.7789 - 967ms/epoch - 1ms/step
# Epoch 278/500
# 855/855 - 1s - loss: 0.7649 - accuracy: 0.7181 - 1s/epoch - 1ms/step
# Epoch 279/500
# 855/855 - 1s - loss: 0.6171 - accuracy: 0.7731 - 860ms/epoch - 1ms/step
# Epoch 280/500
# 855/855 - 1s - loss: 0.7181 - accuracy: 0.7322 - 792ms/epoch - 926us/step
# Epoch 281/500
# 855/855 - 2s - loss: 0.6890 - accuracy: 0.7626 - 2s/epoch - 2ms/step
# Epoch 282/500
# 855/855 - 1s - loss: 0.7031 - accuracy: 0.7532 - 783ms/epoch - 916us/step
# Epoch 283/500
# 855/855 - 1s - loss: 0.6049 - accuracy: 0.7708 - 687ms/epoch - 804us/step
# Epoch 284/500
# 855/855 - 1s - loss: 0.8274 - accuracy: 0.7333 - 659ms/epoch - 771us/step
# Epoch 285/500
# 855/855 - 1s - loss: 0.6216 - accuracy: 0.7637 - 787ms/epoch - 921us/step
# Epoch 286/500
# 855/855 - 1s - loss: 0.6006 - accuracy: 0.7684 - 687ms/epoch - 804us/step
# Epoch 287/500
# 855/855 - 1s - loss: 0.6486 - accuracy: 0.7520 - 658ms/epoch - 770us/step
# Epoch 288/500
# 855/855 - 1s - loss: 0.6031 - accuracy: 0.7673 - 698ms/epoch - 817us/step
# Epoch 289/500
# 855/855 - 1s - loss: 0.9091 - accuracy: 0.7275 - 683ms/epoch - 798us/step
# Epoch 290/500
# 855/855 - 1s - loss: 0.6104 - accuracy: 0.7719 - 692ms/epoch - 809us/step
# Epoch 291/500
# 855/855 - 1s - loss: 0.6775 - accuracy: 0.7673 - 624ms/epoch - 730us/step
# Epoch 292/500
# 855/855 - 1s - loss: 0.5558 - accuracy: 0.7860 - 921ms/epoch - 1ms/step
# Epoch 293/500
# 855/855 - 1s - loss: 0.8162 - accuracy: 0.7392 - 1s/epoch - 1ms/step
# Epoch 294/500
# 855/855 - 1s - loss: 0.6627 - accuracy: 0.7614 - 811ms/epoch - 949us/step
# Epoch 295/500
# 855/855 - 1s - loss: 0.6719 - accuracy: 0.7673 - 1s/epoch - 1ms/step
# Epoch 296/500
# 855/855 - 2s - loss: 0.6848 - accuracy: 0.7579 - 2s/epoch - 2ms/step
# Epoch 297/500
# 855/855 - 1s - loss: 0.7449 - accuracy: 0.7404 - 1s/epoch - 2ms/step
# Epoch 298/500
# 855/855 - 1s - loss: 0.7507 - accuracy: 0.7509 - 783ms/epoch - 916us/step
# Epoch 299/500
# 855/855 - 1s - loss: 0.5721 - accuracy: 0.7801 - 1s/epoch - 1ms/step
# Epoch 300/500
# 855/855 - 1s - loss: 0.6769 - accuracy: 0.7696 - 820ms/epoch - 959us/step
# Epoch 301/500
# 855/855 - 1s - loss: 0.6928 - accuracy: 0.7415 - 873ms/epoch - 1ms/step
# Epoch 302/500
# 855/855 - 1s - loss: 0.6385 - accuracy: 0.7602 - 1s/epoch - 2ms/step
# Epoch 303/500
# 855/855 - 1s - loss: 0.6647 - accuracy: 0.7637 - 847ms/epoch - 991us/step
# Epoch 304/500
# 855/855 - 1s - loss: 0.6214 - accuracy: 0.7719 - 956ms/epoch - 1ms/step
# Epoch 305/500
# 855/855 - 1s - loss: 0.6645 - accuracy: 0.7579 - 797ms/epoch - 932us/step
# Epoch 306/500
# 855/855 - 1s - loss: 0.8438 - accuracy: 0.7135 - 1s/epoch - 1ms/step
# Epoch 307/500
# 855/855 - 1s - loss: 0.7911 - accuracy: 0.7520 - 957ms/epoch - 1ms/step
# Epoch 308/500
# 855/855 - 1s - loss: 0.4910 - accuracy: 0.8035 - 1s/epoch - 1ms/step
# Epoch 309/500
# 855/855 - 1s - loss: 0.5840 - accuracy: 0.7766 - 1s/epoch - 1ms/step
# Epoch 310/500
# 855/855 - 1s - loss: 0.6908 - accuracy: 0.7520 - 1s/epoch - 1ms/step
# Epoch 311/500
# 855/855 - 1s - loss: 0.5241 - accuracy: 0.8105 - 998ms/epoch - 1ms/step
# Epoch 312/500
# 855/855 - 1s - loss: 0.9287 - accuracy: 0.6947 - 787ms/epoch - 920us/step
# Epoch 313/500
# 855/855 - 1s - loss: 0.6063 - accuracy: 0.7778 - 1s/epoch - 1ms/step
# Epoch 314/500
# 855/855 - 1s - loss: 0.5091 - accuracy: 0.8105 - 1s/epoch - 2ms/step
# Epoch 315/500
# 855/855 - 1s - loss: 0.5804 - accuracy: 0.7918 - 738ms/epoch - 863us/step
# Epoch 316/500
# 855/855 - 1s - loss: 0.6650 - accuracy: 0.7485 - 673ms/epoch - 788us/step
# Epoch 317/500
# 855/855 - 1s - loss: 0.6969 - accuracy: 0.7497 - 785ms/epoch - 918us/step
# Epoch 318/500
# 855/855 - 2s - loss: 0.9292 - accuracy: 0.7076 - 2s/epoch - 2ms/step
# Epoch 319/500
# 855/855 - 2s - loss: 0.7392 - accuracy: 0.7825 - 2s/epoch - 2ms/step
# Epoch 320/500
# 855/855 - 1s - loss: 0.6815 - accuracy: 0.7474 - 799ms/epoch - 934us/step
# Epoch 321/500
# 855/855 - 1s - loss: 0.5626 - accuracy: 0.7848 - 941ms/epoch - 1ms/step
# Epoch 322/500
# 855/855 - 1s - loss: 0.6616 - accuracy: 0.7743 - 1s/epoch - 2ms/step
# Epoch 323/500
# 855/855 - 1s - loss: 0.7726 - accuracy: 0.7556 - 613ms/epoch - 717us/step
# Epoch 324/500
# 855/855 - 2s - loss: 0.5554 - accuracy: 0.7871 - 2s/epoch - 2ms/step
# Epoch 325/500
# 855/855 - 1s - loss: 0.6436 - accuracy: 0.7766 - 1s/epoch - 1ms/step
# Epoch 326/500
# 855/855 - 2s - loss: 0.6800 - accuracy: 0.7731 - 2s/epoch - 2ms/step
# Epoch 327/500
# 855/855 - 1s - loss: 0.6592 - accuracy: 0.7825 - 1s/epoch - 1ms/step
# Epoch 328/500
# 855/855 - 1s - loss: 0.7077 - accuracy: 0.7509 - 1s/epoch - 1ms/step
# Epoch 329/500
# 855/855 - 2s - loss: 0.7500 - accuracy: 0.7567 - 2s/epoch - 2ms/step
# Epoch 330/500
# 855/855 - 1s - loss: 0.6895 - accuracy: 0.7778 - 1s/epoch - 1ms/step
# Epoch 331/500
# 855/855 - 1s - loss: 0.8865 - accuracy: 0.7228 - 779ms/epoch - 911us/step
# Epoch 332/500
# 855/855 - 1s - loss: 0.6626 - accuracy: 0.7556 - 1s/epoch - 1ms/step
# Epoch 333/500
# 855/855 - 1s - loss: 0.5573 - accuracy: 0.7766 - 1s/epoch - 1ms/step
# Epoch 334/500
# 855/855 - 1s - loss: 0.4693 - accuracy: 0.8035 - 1s/epoch - 1ms/step
# Epoch 335/500
# 855/855 - 1s - loss: 0.6001 - accuracy: 0.7906 - 1s/epoch - 2ms/step
# Epoch 336/500
# 855/855 - 1s - loss: 0.8247 - accuracy: 0.7532 - 1s/epoch - 2ms/step
# Epoch 337/500
# 855/855 - 2s - loss: 0.8593 - accuracy: 0.7392 - 2s/epoch - 2ms/step
# Epoch 338/500
# 855/855 - 1s - loss: 0.5723 - accuracy: 0.7930 - 940ms/epoch - 1ms/step
# Epoch 339/500
# 855/855 - 1s - loss: 0.6863 - accuracy: 0.7626 - 1s/epoch - 1ms/step
# Epoch 340/500
# 855/855 - 1s - loss: 0.6526 - accuracy: 0.7708 - 1s/epoch - 1ms/step
# Epoch 341/500
# 855/855 - 1s - loss: 0.4504 - accuracy: 0.8094 - 1s/epoch - 1ms/step
# Epoch 342/500
# 855/855 - 1s - loss: 0.8624 - accuracy: 0.7439 - 732ms/epoch - 856us/step
# Epoch 343/500
# 855/855 - 1s - loss: 0.7503 - accuracy: 0.7368 - 885ms/epoch - 1ms/step
# Epoch 344/500
# 855/855 - 1s - loss: 0.6678 - accuracy: 0.7649 - 953ms/epoch - 1ms/step
# Epoch 345/500
# 855/855 - 1s - loss: 0.7262 - accuracy: 0.7801 - 1s/epoch - 2ms/step
# Epoch 346/500
# 855/855 - 1s - loss: 0.4908 - accuracy: 0.7942 - 1s/epoch - 2ms/step
# Epoch 347/500
# 855/855 - 2s - loss: 0.7102 - accuracy: 0.7462 - 2s/epoch - 2ms/step
# Epoch 348/500
# 855/855 - 2s - loss: 0.7414 - accuracy: 0.7567 - 2s/epoch - 3ms/step
# Epoch 349/500
# 855/855 - 1s - loss: 0.6234 - accuracy: 0.7789 - 1s/epoch - 1ms/step
# Epoch 350/500
# 855/855 - 1s - loss: 0.6804 - accuracy: 0.7696 - 852ms/epoch - 997us/step
# Epoch 351/500
# 855/855 - 3s - loss: 0.7532 - accuracy: 0.7450 - 3s/epoch - 3ms/step
# Epoch 352/500
# 855/855 - 2s - loss: 0.5213 - accuracy: 0.7942 - 2s/epoch - 2ms/step
# Epoch 353/500
# 855/855 - 1s - loss: 0.6179 - accuracy: 0.7918 - 839ms/epoch - 982us/step
# Epoch 354/500
# 855/855 - 1s - loss: 0.7502 - accuracy: 0.7556 - 935ms/epoch - 1ms/step
# Epoch 355/500
# 855/855 - 1s - loss: 0.7367 - accuracy: 0.7579 - 926ms/epoch - 1ms/step
# Epoch 356/500
# 855/855 - 1s - loss: 0.6656 - accuracy: 0.7684 - 874ms/epoch - 1ms/step
# Epoch 357/500
# 855/855 - 1s - loss: 0.6672 - accuracy: 0.7778 - 1s/epoch - 2ms/step
# Epoch 358/500
# 855/855 - 2s - loss: 0.7583 - accuracy: 0.7614 - 2s/epoch - 2ms/step
# Epoch 359/500
# 855/855 - 1s - loss: 0.7103 - accuracy: 0.7474 - 1s/epoch - 2ms/step
# Epoch 360/500
# 855/855 - 2s - loss: 0.6043 - accuracy: 0.7708 - 2s/epoch - 2ms/step
# Epoch 361/500
# 855/855 - 1s - loss: 0.7042 - accuracy: 0.7544 - 1s/epoch - 2ms/step
# Epoch 362/500
# 855/855 - 2s - loss: 0.6850 - accuracy: 0.7591 - 2s/epoch - 2ms/step
# Epoch 363/500
# 855/855 - 2s - loss: 0.5690 - accuracy: 0.7895 - 2s/epoch - 2ms/step
# Epoch 364/500
# 855/855 - 2s - loss: 0.6951 - accuracy: 0.7556 - 2s/epoch - 2ms/step
# Epoch 365/500
# 855/855 - 2s - loss: 0.5273 - accuracy: 0.7930 - 2s/epoch - 2ms/step
# Epoch 366/500
# 855/855 - 1s - loss: 0.4859 - accuracy: 0.8199 - 1s/epoch - 2ms/step
# Epoch 367/500
# 855/855 - 1s - loss: 0.8110 - accuracy: 0.7509 - 924ms/epoch - 1ms/step
# Epoch 368/500
# 855/855 - 2s - loss: 0.5576 - accuracy: 0.7988 - 2s/epoch - 3ms/step
# Epoch 369/500
# 855/855 - 1s - loss: 0.7245 - accuracy: 0.7602 - 1s/epoch - 2ms/step
# Epoch 370/500
# 855/855 - 1s - loss: 0.7253 - accuracy: 0.7509 - 555ms/epoch - 649us/step
# Epoch 371/500
# 855/855 - 0s - loss: 0.5208 - accuracy: 0.7977 - 432ms/epoch - 506us/step
# Epoch 372/500
# 855/855 - 1s - loss: 0.5542 - accuracy: 0.7906 - 586ms/epoch - 686us/step
# Epoch 373/500
# 855/855 - 2s - loss: 0.7582 - accuracy: 0.7415 - 2s/epoch - 2ms/step
# Epoch 374/500
# 855/855 - 0s - loss: 0.5843 - accuracy: 0.7906 - 405ms/epoch - 474us/step
# Epoch 375/500
# 855/855 - 1s - loss: 0.6757 - accuracy: 0.7579 - 701ms/epoch - 820us/step
# Epoch 376/500
# 855/855 - 1s - loss: 0.7481 - accuracy: 0.7637 - 1s/epoch - 2ms/step
# Epoch 377/500
# 855/855 - 1s - loss: 0.5479 - accuracy: 0.7918 - 1s/epoch - 2ms/step
# Epoch 378/500
# 855/855 - 2s - loss: 0.9688 - accuracy: 0.7275 - 2s/epoch - 3ms/step
# Epoch 379/500
# 855/855 - 2s - loss: 0.5538 - accuracy: 0.7848 - 2s/epoch - 2ms/step
# Epoch 380/500
# 855/855 - 1s - loss: 0.5854 - accuracy: 0.7860 - 1s/epoch - 2ms/step
# Epoch 381/500
# 855/855 - 2s - loss: 0.6585 - accuracy: 0.7778 - 2s/epoch - 3ms/step
# Epoch 382/500
# 855/855 - 3s - loss: 0.9458 - accuracy: 0.7368 - 3s/epoch - 3ms/step
# Epoch 383/500
# 855/855 - 1s - loss: 0.7655 - accuracy: 0.7404 - 1s/epoch - 1ms/step
# Epoch 384/500
# 855/855 - 2s - loss: 0.6483 - accuracy: 0.7789 - 2s/epoch - 2ms/step
# Epoch 385/500
# 855/855 - 1s - loss: 0.4992 - accuracy: 0.7988 - 1s/epoch - 2ms/step
# Epoch 386/500
# 855/855 - 1s - loss: 0.6712 - accuracy: 0.7918 - 1s/epoch - 2ms/step
# Epoch 387/500
# 855/855 - 2s - loss: 0.5996 - accuracy: 0.7754 - 2s/epoch - 2ms/step
# Epoch 388/500
# 855/855 - 2s - loss: 0.5758 - accuracy: 0.7883 - 2s/epoch - 2ms/step
# Epoch 389/500
# 855/855 - 2s - loss: 0.6080 - accuracy: 0.7930 - 2s/epoch - 3ms/step
# Epoch 390/500
# 855/855 - 1s - loss: 0.7877 - accuracy: 0.7251 - 1s/epoch - 1ms/step
# Epoch 391/500
# 855/855 - 1s - loss: 0.8057 - accuracy: 0.7567 - 1s/epoch - 2ms/step
# Epoch 392/500
# 855/855 - 1s - loss: 0.4902 - accuracy: 0.8047 - 1s/epoch - 1ms/step
# Epoch 393/500
# 855/855 - 1s - loss: 0.7518 - accuracy: 0.7567 - 963ms/epoch - 1ms/step
# Epoch 394/500
# 855/855 - 2s - loss: 0.6616 - accuracy: 0.7661 - 2s/epoch - 3ms/step
# Epoch 395/500
# 855/855 - 2s - loss: 0.6028 - accuracy: 0.7754 - 2s/epoch - 2ms/step
# Epoch 396/500
# 855/855 - 2s - loss: 0.7833 - accuracy: 0.7778 - 2s/epoch - 2ms/step
# Epoch 397/500
# 855/855 - 2s - loss: 0.7393 - accuracy: 0.7649 - 2s/epoch - 2ms/step
# Epoch 398/500
# 855/855 - 2s - loss: 0.5810 - accuracy: 0.7860 - 2s/epoch - 2ms/step
# Epoch 399/500
# 855/855 - 2s - loss: 0.4445 - accuracy: 0.8164 - 2s/epoch - 2ms/step
# Epoch 400/500
# 855/855 - 1s - loss: 1.0620 - accuracy: 0.7053 - 1s/epoch - 2ms/step
# Epoch 401/500
# 855/855 - 2s - loss: 0.6690 - accuracy: 0.7719 - 2s/epoch - 3ms/step
# Epoch 402/500
# 855/855 - 2s - loss: 0.6343 - accuracy: 0.8000 - 2s/epoch - 2ms/step
# Epoch 403/500
# 855/855 - 2s - loss: 0.4820 - accuracy: 0.8000 - 2s/epoch - 2ms/step
# Epoch 404/500
# 855/855 - 2s - loss: 0.5629 - accuracy: 0.7965 - 2s/epoch - 3ms/step
# Epoch 405/500
# 855/855 - 2s - loss: 0.8076 - accuracy: 0.7532 - 2s/epoch - 2ms/step
# Epoch 406/500
# 855/855 - 2s - loss: 0.6778 - accuracy: 0.7661 - 2s/epoch - 2ms/step
# Epoch 407/500
# 855/855 - 1s - loss: 0.6715 - accuracy: 0.7696 - 1s/epoch - 2ms/step
# Epoch 408/500
# 855/855 - 2s - loss: 0.7441 - accuracy: 0.7801 - 2s/epoch - 2ms/step
# Epoch 409/500
# 855/855 - 1s - loss: 0.5859 - accuracy: 0.7836 - 1s/epoch - 2ms/step
# Epoch 410/500
# 855/855 - 1s - loss: 0.6064 - accuracy: 0.8070 - 846ms/epoch - 990us/step
# Epoch 411/500
# 855/855 - 1s - loss: 0.6265 - accuracy: 0.7754 - 1s/epoch - 1ms/step
# Epoch 412/500
# 855/855 - 1s - loss: 0.5569 - accuracy: 0.7918 - 1s/epoch - 1ms/step
# Epoch 413/500
# 855/855 - 1s - loss: 1.0671 - accuracy: 0.7088 - 1s/epoch - 2ms/step
# Epoch 414/500
# 855/855 - 2s - loss: 0.6133 - accuracy: 0.7895 - 2s/epoch - 2ms/step
# Epoch 415/500
# 855/855 - 1s - loss: 0.3846 - accuracy: 0.8433 - 1s/epoch - 1ms/step
# Epoch 416/500
# 855/855 - 1s - loss: 0.6487 - accuracy: 0.7801 - 602ms/epoch - 704us/step
# Epoch 417/500
# 855/855 - 2s - loss: 0.6714 - accuracy: 0.7860 - 2s/epoch - 2ms/step
# Epoch 418/500
# 855/855 - 1s - loss: 0.5999 - accuracy: 0.7977 - 836ms/epoch - 978us/step
# Epoch 419/500
# 855/855 - 2s - loss: 0.6894 - accuracy: 0.7696 - 2s/epoch - 2ms/step
# Epoch 420/500
# 855/855 - 2s - loss: 0.5890 - accuracy: 0.7906 - 2s/epoch - 2ms/step
# Epoch 421/500
# 855/855 - 2s - loss: 0.5251 - accuracy: 0.8070 - 2s/epoch - 2ms/step
# Epoch 422/500
# 855/855 - 1s - loss: 0.6111 - accuracy: 0.7789 - 1s/epoch - 2ms/step
# Epoch 423/500
# 855/855 - 1s - loss: 0.7097 - accuracy: 0.7532 - 982ms/epoch - 1ms/step
# Epoch 424/500
# 855/855 - 1s - loss: 0.5638 - accuracy: 0.8023 - 1s/epoch - 1ms/step
# Epoch 425/500
# 855/855 - 1s - loss: 0.5012 - accuracy: 0.8094 - 1s/epoch - 2ms/step
# Epoch 426/500
# 855/855 - 1s - loss: 0.7294 - accuracy: 0.7626 - 884ms/epoch - 1ms/step
# Epoch 427/500
# 855/855 - 1s - loss: 0.6538 - accuracy: 0.7813 - 1s/epoch - 2ms/step
# Epoch 428/500
# 855/855 - 1s - loss: 0.6539 - accuracy: 0.7848 - 1s/epoch - 1ms/step
# Epoch 429/500
# 855/855 - 3s - loss: 0.8339 - accuracy: 0.7251 - 3s/epoch - 3ms/step
# Epoch 430/500
# 855/855 - 2s - loss: 0.5708 - accuracy: 0.7918 - 2s/epoch - 3ms/step
# Epoch 431/500
# 855/855 - 2s - loss: 0.7016 - accuracy: 0.7848 - 2s/epoch - 2ms/step
# Epoch 432/500
# 855/855 - 1s - loss: 0.6887 - accuracy: 0.7860 - 1s/epoch - 1ms/step
# Epoch 433/500
# 855/855 - 3s - loss: 0.4521 - accuracy: 0.8082 - 3s/epoch - 3ms/step
# Epoch 434/500
# 855/855 - 1s - loss: 0.7318 - accuracy: 0.7684 - 944ms/epoch - 1ms/step
# Epoch 435/500
# 855/855 - 1s - loss: 0.7236 - accuracy: 0.7684 - 1s/epoch - 2ms/step
# Epoch 436/500
# 855/855 - 3s - loss: 0.6121 - accuracy: 0.7895 - 3s/epoch - 3ms/step
# Epoch 437/500
# 855/855 - 1s - loss: 0.5204 - accuracy: 0.8047 - 1s/epoch - 1ms/step
# Epoch 438/500
# 855/855 - 2s - loss: 0.8737 - accuracy: 0.7415 - 2s/epoch - 2ms/step
# Epoch 439/500
# 855/855 - 2s - loss: 0.5889 - accuracy: 0.7860 - 2s/epoch - 3ms/step
# Epoch 440/500
# 855/855 - 2s - loss: 0.6357 - accuracy: 0.7825 - 2s/epoch - 2ms/step
# Epoch 441/500
# 855/855 - 1s - loss: 0.6853 - accuracy: 0.7766 - 578ms/epoch - 677us/step
# Epoch 442/500
# 855/855 - 1s - loss: 0.6692 - accuracy: 0.7906 - 712ms/epoch - 833us/step
# Epoch 443/500
# 855/855 - 1s - loss: 0.6597 - accuracy: 0.7626 - 816ms/epoch - 954us/step
# Epoch 444/500
# 855/855 - 2s - loss: 0.6383 - accuracy: 0.7754 - 2s/epoch - 2ms/step
# Epoch 445/500
# 855/855 - 1s - loss: 0.7533 - accuracy: 0.7871 - 1s/epoch - 1ms/step
# Epoch 446/500
# 855/855 - 1s - loss: 0.8233 - accuracy: 0.7637 - 1s/epoch - 2ms/step
# Epoch 447/500
# 855/855 - 1s - loss: 0.5186 - accuracy: 0.8058 - 1s/epoch - 1ms/step
# Epoch 448/500
# 855/855 - 1s - loss: 0.6628 - accuracy: 0.7626 - 1s/epoch - 2ms/step
# Epoch 449/500
# 855/855 - 1s - loss: 0.5056 - accuracy: 0.8152 - 1s/epoch - 1ms/step
# Epoch 450/500
# 855/855 - 2s - loss: 0.6646 - accuracy: 0.7696 - 2s/epoch - 2ms/step
# Epoch 451/500
# 855/855 - 1s - loss: 0.7476 - accuracy: 0.7579 - 1s/epoch - 1ms/step
# Epoch 452/500
# 855/855 - 2s - loss: 0.7843 - accuracy: 0.7474 - 2s/epoch - 2ms/step
# Epoch 453/500
# 855/855 - 2s - loss: 0.5758 - accuracy: 0.8012 - 2s/epoch - 2ms/step
# Epoch 454/500
# 855/855 - 2s - loss: 0.8013 - accuracy: 0.7474 - 2s/epoch - 2ms/step
# Epoch 455/500
# 855/855 - 2s - loss: 0.5928 - accuracy: 0.7836 - 2s/epoch - 2ms/step
# Epoch 456/500
# 855/855 - 1s - loss: 0.6720 - accuracy: 0.7766 - 1s/epoch - 1ms/step
# Epoch 457/500
# 855/855 - 1s - loss: 0.5447 - accuracy: 0.7953 - 1s/epoch - 1ms/step
# Epoch 458/500
# 855/855 - 2s - loss: 0.4561 - accuracy: 0.8082 - 2s/epoch - 2ms/step
# Epoch 459/500
# 855/855 - 2s - loss: 0.7614 - accuracy: 0.7649 - 2s/epoch - 2ms/step
# Epoch 460/500
# 855/855 - 2s - loss: 0.6918 - accuracy: 0.7906 - 2s/epoch - 3ms/step
# Epoch 461/500
# 855/855 - 1s - loss: 0.6932 - accuracy: 0.7871 - 1s/epoch - 2ms/step
# Epoch 462/500
# 855/855 - 1s - loss: 0.5808 - accuracy: 0.7930 - 1s/epoch - 2ms/step
# Epoch 463/500
# 855/855 - 2s - loss: 0.5851 - accuracy: 0.7860 - 2s/epoch - 2ms/step
# Epoch 464/500
# 855/855 - 1s - loss: 0.7620 - accuracy: 0.7579 - 870ms/epoch - 1ms/step
# Epoch 465/500
# 855/855 - 1s - loss: 0.6448 - accuracy: 0.7942 - 1s/epoch - 1ms/step
# Epoch 466/500
# 855/855 - 2s - loss: 0.6017 - accuracy: 0.7825 - 2s/epoch - 2ms/step
# Epoch 467/500
# 855/855 - 1s - loss: 0.6966 - accuracy: 0.7637 - 1s/epoch - 2ms/step
# Epoch 468/500
# 855/855 - 1s - loss: 0.5568 - accuracy: 0.8035 - 1s/epoch - 1ms/step
# Epoch 469/500
# 855/855 - 1s - loss: 0.6529 - accuracy: 0.7813 - 934ms/epoch - 1ms/step
# Epoch 470/500
# 855/855 - 1s - loss: 0.6614 - accuracy: 0.7825 - 1s/epoch - 2ms/step
# Epoch 471/500
# 855/855 - 2s - loss: 0.9208 - accuracy: 0.7462 - 2s/epoch - 2ms/step
# Epoch 472/500
# 855/855 - 1s - loss: 0.5551 - accuracy: 0.7988 - 1s/epoch - 2ms/step
# Epoch 473/500
# 855/855 - 1s - loss: 0.5790 - accuracy: 0.7860 - 803ms/epoch - 940us/step
# Epoch 474/500
# 855/855 - 1s - loss: 0.8731 - accuracy: 0.7474 - 828ms/epoch - 968us/step
# Epoch 475/500
# 855/855 - 1s - loss: 0.5409 - accuracy: 0.8047 - 1s/epoch - 1ms/step
# Epoch 476/500
# 855/855 - 1s - loss: 0.5808 - accuracy: 0.7871 - 880ms/epoch - 1ms/step
# Epoch 477/500
# 855/855 - 1s - loss: 0.5966 - accuracy: 0.7848 - 1s/epoch - 1ms/step
# Epoch 478/500
# 855/855 - 1s - loss: 0.6374 - accuracy: 0.7860 - 1s/epoch - 1ms/step
# Epoch 479/500
# 855/855 - 1s - loss: 0.6787 - accuracy: 0.7719 - 1s/epoch - 1ms/step
# Epoch 480/500
# 855/855 - 1s - loss: 0.6771 - accuracy: 0.7848 - 1s/epoch - 1ms/step
# Epoch 481/500
# 855/855 - 1s - loss: 0.8712 - accuracy: 0.7485 - 1s/epoch - 2ms/step
# Epoch 482/500
# 855/855 - 1s - loss: 0.6777 - accuracy: 0.7871 - 779ms/epoch - 911us/step
# Epoch 483/500
# 855/855 - 1s - loss: 0.4547 - accuracy: 0.8257 - 1s/epoch - 1ms/step
# Epoch 484/500
# 855/855 - 1s - loss: 0.4165 - accuracy: 0.8304 - 1s/epoch - 1ms/step
# Epoch 485/500
# 855/855 - 1s - loss: 0.7115 - accuracy: 0.7602 - 665ms/epoch - 778us/step
# Epoch 486/500
# 855/855 - 2s - loss: 0.9144 - accuracy: 0.7275 - 2s/epoch - 2ms/step
# Epoch 487/500
# 855/855 - 1s - loss: 0.4849 - accuracy: 0.8070 - 1s/epoch - 1ms/step
# Epoch 488/500
# 855/855 - 1s - loss: 0.6277 - accuracy: 0.7942 - 1s/epoch - 1ms/step
# Epoch 489/500
# 855/855 - 1s - loss: 0.5820 - accuracy: 0.7895 - 892ms/epoch - 1ms/step
# Epoch 490/500
# 855/855 - 1s - loss: 0.6556 - accuracy: 0.7766 - 572ms/epoch - 669us/step
# Epoch 491/500
# 855/855 - 1s - loss: 0.4961 - accuracy: 0.8129 - 603ms/epoch - 705us/step
# Epoch 492/500
# 855/855 - 1s - loss: 0.6277 - accuracy: 0.7766 - 1s/epoch - 1ms/step
# Epoch 493/500
# 855/855 - 1s - loss: 0.6654 - accuracy: 0.7743 - 989ms/epoch - 1ms/step
# Epoch 494/500
# 855/855 - 1s - loss: 0.6311 - accuracy: 0.7930 - 1s/epoch - 2ms/step
# Epoch 495/500
# 855/855 - 1s - loss: 0.5519 - accuracy: 0.7953 - 762ms/epoch - 891us/step
# Epoch 496/500
# 855/855 - 1s - loss: 0.3975 - accuracy: 0.8327 - 729ms/epoch - 853us/step
# Epoch 497/500
# 855/855 - 1s - loss: 0.8230 - accuracy: 0.7357 - 854ms/epoch - 999us/step
# Epoch 498/500
# 855/855 - 1s - loss: 0.9189 - accuracy: 0.7310 - 1s/epoch - 1ms/step
# Epoch 499/500
# 855/855 - 1s - loss: 0.4399 - accuracy: 0.8234 - 754ms/epoch - 882us/step
# Epoch 500/500
# 855/855 - 1s - loss: 0.5922 - accuracy: 0.8012 - 1s/epoch - 1ms/step

# %%
# 문자 생성
seed = "딥 러닝이"  # 시드 문자열 길이를 seq_length와 동일하게 설정
generated_text = seed

input_seq = np.array( [char_to_idx[char] for char in seed] )
input_seq = input_seq.reshape(1, seq_length)


for _ in range(50):
    predicted_idx = np.argmax( model.predict(input_seq) )
    predicted_char = idx_to_char[predicted_idx]
    generated_text += predicted_char
    
    print('input_seq', input_seq)
    print('predicted_idx', predicted_idx)
    
    input_seq = np.concatenate((input_seq[:, 1:], np.array(predicted_idx).reshape(1, 1)), axis=1)

print("생성된 문장:", generated_text)
# Out:
# 1/1 [==============================] - 0s 8ms/step
# input_seq [[ 60   1  67  46 135]]
# predicted_idx 78
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[  1  67  46 135  78]]
# predicted_idx 1
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[ 67  46 135  78   1]]
# predicted_idx 28
# 1/1 [==============================] - 0s 14ms/step
# input_seq [[ 46 135  78   1  28]]
# predicted_idx 92
# 1/1 [==============================] - 0s 13ms/step
# input_seq [[135  78   1  28  92]]
# predicted_idx 56
# 1/1 [==============================] - 0s 14ms/step
# input_seq [[78  1 28 92 56]]
# predicted_idx 46
# 1/1 [==============================] - 0s 13ms/step
# input_seq [[ 1 28 92 56 46]]
# predicted_idx 47
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[28 92 56 46 47]]
# predicted_idx 6
# 1/1 [==============================] - 0s 16ms/step
# input_seq [[92 56 46 47  6]]
# predicted_idx 1
# 1/1 [==============================] - 0s 14ms/step
# input_seq [[56 46 47  6  1]]
# predicted_idx 151
# 1/1 [==============================] - 0s 14ms/step
# input_seq [[ 46  47   6   1 151]]
# predicted_idx 51
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[ 47   6   1 151  51]]
# predicted_idx 1
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[  6   1 151  51   1]]
# predicted_idx 171
# 1/1 [==============================] - 0s 8ms/step
# input_seq [[  1 151  51   1 171]]
# predicted_idx 110
# 1/1 [==============================] - 0s 8ms/step
# input_seq [[151  51   1 171 110]]
# predicted_idx 120
# 1/1 [==============================] - 0s 8ms/step
# input_seq [[ 51   1 171 110 120]]
# predicted_idx 101
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[  1 171 110 120 101]]
# predicted_idx 1
# 1/1 [==============================] - 0s 14ms/step
# input_seq [[171 110 120 101   1]]
# predicted_idx 171
# 1/1 [==============================] - 0s 12ms/step
# input_seq [[110 120 101   1 171]]
# predicted_idx 110
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[120 101   1 171 110]]
# predicted_idx 132
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[101   1 171 110 132]]
# predicted_idx 1
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[  1 171 110 132   1]]
# predicted_idx 129
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[171 110 132   1 129]]
# predicted_idx 172
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[110 132   1 129 172]]
# predicted_idx 1
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[132   1 129 172   1]]
# predicted_idx 100
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[  1 129 172   1 100]]
# predicted_idx 169
# 1/1 [==============================] - 0s 8ms/step
# input_seq [[129 172   1 100 169]]
# predicted_idx 1
# 1/1 [==============================] - 0s 13ms/step
# input_seq [[172   1 100 169   1]]
# predicted_idx 49
# 1/1 [==============================] - 0s 14ms/step
# input_seq [[  1 100 169   1  49]]
# predicted_idx 135
# 1/1 [==============================] - 0s 13ms/step
# input_seq [[100 169   1  49 135]]
# predicted_idx 159
# 1/1 [==============================] - 0s 10ms/step
# input_seq [[169   1  49 135 159]]
# predicted_idx 42
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[  1  49 135 159  42]]
# predicted_idx 1
# 1/1 [==============================] - 0s 8ms/step
# input_seq [[ 49 135 159  42   1]]
# predicted_idx 138
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[135 159  42   1 138]]
# predicted_idx 68
# 1/1 [==============================] - 0s 15ms/step
# input_seq [[159  42   1 138  68]]
# predicted_idx 23
# 1/1 [==============================] - 0s 15ms/step
# input_seq [[ 42   1 138  68  23]]
# predicted_idx 1
# 1/1 [==============================] - 0s 13ms/step
# input_seq [[  1 138  68  23   1]]
# predicted_idx 140
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[138  68  23   1 140]]
# predicted_idx 109
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[ 68  23   1 140 109]]
# predicted_idx 120
# 1/1 [==============================] - 0s 8ms/step
# input_seq [[ 23   1 140 109 120]]
# predicted_idx 101
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[  1 140 109 120 101]]
# predicted_idx 1
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[140 109 120 101   1]]
# predicted_idx 97
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[109 120 101   1  97]]
# predicted_idx 113
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[120 101   1  97 113]]
# predicted_idx 170
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[101   1  97 113 170]]
# predicted_idx 131
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[  1  97 113 170 131]]
# predicted_idx 1
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[ 97 113 170 131   1]]
# predicted_idx 136
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[113 170 131   1 136]]
# predicted_idx 22
# 1/1 [==============================] - 0s 9ms/step
# input_seq [[170 131   1 136  22]]
# predicted_idx 134
# 1/1 [==============================] - 0s 8ms/step
# input_seq [[131   1 136  22 134]]
# predicted_idx 1
# 생성된 문장: 딥 러닝이며 결복됩닝다. 지도 학습에서 학습을 위한 샘플 데이터는 입력값 자스에서 사신하은 인간의

# %%
model.save('model/rnn.h5')
